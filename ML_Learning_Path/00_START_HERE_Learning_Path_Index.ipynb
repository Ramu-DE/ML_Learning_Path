# %% [markdown]
# # Data Science & Machine Learning — Complete Learning Path
# ## From Zero to Practitioner
#
# This folder contains **19 Jupyter notebooks** taking you from absolute beginner to advanced ML practitioner.
# Each notebook builds on the previous one.
#
# ---
#
# ## How to Use This Curriculum
#
# 1. Open notebooks **in order** (01 → 19)
# 2. **Run every code cell** — don't just read
# 3. **Modify the examples** with your own numbers
# 4. **Complete the exercises** at the end of each notebook
#
# ---
#
# ## Learning Path
#
# ### Foundation (Notebooks 01–04)
# | # | Notebook | Topics | Difficulty | Time |
# |---|---|---|---|---|
# | 01 | `01_Python_Basics_for_DataScience.ipynb` | Variables, collections, functions, comprehensions | Beginner | 2h |
# | 02 | `02_NumPy_Fundamentals.ipynb` | Arrays, broadcasting, linear algebra | Beginner | 2.5h |
# | 03 | `03_Pandas_Data_Analysis.ipynb` | DataFrames, groupby, merge, pivot | Beginner | 3h |
# | 04 | `04_Data_Visualization_Matplotlib_Seaborn.ipynb` | Line, bar, scatter, heatmap, seaborn | Beginner | 2.5h |
#
# ### Data Science Skills (Notebooks 05–06)
# | # | Notebook | Topics | Difficulty | Time |
# |---|---|---|---|---|
# | 05 | `05_Exploratory_Data_Analysis.ipynb` | EDA framework, distributions, outliers | Intermediate | 3h |
# | 06 | `06_Feature_Engineering_Preprocessing.ipynb` | Imputation, encoding, scaling, pipelines | Intermediate | 2.5h |
#
# ### Machine Learning — Supervised (Notebooks 07–11)
# | # | Notebook | Topics | Difficulty | Time |
# |---|---|---|---|---|
# | 07 | `07_Linear_Regression.ipynb` | Simple/Multiple LR, Ridge, Lasso, Polynomial | Intermediate | 3h |
# | 08 | `08_Logistic_Regression_Classification.ipynb` | Binary/Multiclass, ROC, Precision-Recall | Intermediate | 3h |
# | 09 | `09_Decision_Trees_Random_Forests.ipynb` | Trees, Random Forest, GridSearchCV | Intermediate | 3h |
# | 10 | `10_SVM_KNN.ipynb` | KNN, SVM (linear + RBF), kernels | Intermediate | 2.5h |
# | 11 | `11_Gradient_Boosting_XGBoost.ipynb` | GBM, XGBoost, learning curves | Int-Advanced | 3h |
#
# ### Machine Learning — Unsupervised (Notebooks 12–13)
# | # | Notebook | Topics | Difficulty | Time |
# |---|---|---|---|---|
# | 12 | `12_Clustering_KMeans_DBSCAN.ipynb` | K-Means, DBSCAN, Hierarchical, Segmentation | Intermediate | 2.5h |
# | 13 | `13_Dimensionality_Reduction_PCA.ipynb` | PCA, t-SNE, scree plot, image compression | Intermediate | 2.5h |
#
# ### Best Practices (Notebook 14)
# | # | Notebook | Topics | Difficulty | Time |
# |---|---|---|---|---|
# | 14 | `14_Model_Selection_CrossValidation.ipynb` | CV, bias-variance, GridSearch, protocol | Intermediate | 2.5h |
#
# ### Advanced Topics (Notebooks 15–19)
# | # | Notebook | Topics | Difficulty | Time |
# |---|---|---|---|---|
# | 15 | `15_Neural_Networks_Introduction.ipynb` | Perceptron, MLP, backprop, Keras | Advanced | 4h |
# | 16 | `16_Time_Series_Analysis.ipynb` | Decomposition, ARIMA, ML for TS | Int-Advanced | 3h |
# | 17 | `17_NLP_Text_Analysis.ipynb` | TF-IDF, Sentiment, Topic Modeling | Int-Advanced | 3h |
# | 18 | `18_End_to_End_ML_Project.ipynb` | Complete pipeline: EDA→Deploy | Advanced | 4h |
# | 19 | `19_Advanced_Topics_Ensemble_Anomaly.ipynb` | Imbalanced data, Anomaly detection, SHAP | Advanced | 3h |
#
# ---
#
# ## Prerequisites
#
# ```bash
# pip install numpy pandas matplotlib seaborn scikit-learn scipy statsmodels joblib
# # Optional advanced:
# pip install xgboost lightgbm tensorflow imbalanced-learn shap
# ```
#
# ---
#
# ## Key Concepts Covered
#
# ✅ Python for Data Science
# ✅ NumPy & Pandas
# ✅ Matplotlib & Seaborn visualizations
# ✅ Full EDA workflow
# ✅ Feature Engineering & Preprocessing
# ✅ Linear & Logistic Regression
# ✅ Decision Trees & Random Forests
# ✅ SVM, KNN
# ✅ Gradient Boosting (XGBoost)
# ✅ K-Means, DBSCAN, Hierarchical Clustering
# ✅ PCA, t-SNE
# ✅ Cross-validation & Model Selection
# ✅ Neural Networks (MLP, intro to Keras)
# ✅ Time Series (ARIMA + ML)
# ✅ NLP (TF-IDF, Sentiment, LDA)
# ✅ End-to-End Project
# ✅ Imbalanced Data, Anomaly Detection, SHAP
#
# ---
#
# ## Real-World Examples in This Course
#
# | Domain | Application |
# |---|---|
# | HR Analytics | Employee salary & attrition prediction |
# | Finance | Credit default & fraud detection |
# | E-commerce | Customer segmentation & churn |
# | Real Estate | House price prediction |
# | Healthcare | Breast cancer classification |
# | Marketing | Bank subscription prediction |
# | Tech | Spam email detection, digit recognition |
# | NLP | Sentiment analysis, topic modeling |
#
# **Total estimated study time: ~55 hours**

# %%
# Quick setup check — run this first!
import sys
packages = ['numpy','pandas','matplotlib','seaborn','sklearn','scipy']
for pkg in packages:
    try:
        mod = __import__(pkg if pkg != 'sklearn' else 'sklearn')
        print(f'  OK  {pkg}')
    except ImportError:
        print(f'  MISSING  {pkg}  -> pip install {pkg}')
print('\nAll set! Start with 01_Python_Basics_for_DataScience.ipynb')
